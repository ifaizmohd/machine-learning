# %%
import pandas as pd

# %%
series = pd.Series(["BMW", "FORD", "SHELBY","FERARI"])

# %%
series
# Out:
# 0       BMW
# 1      FORD
# 2    SHELBY
# 3    FERARI
# dtype: object

# %%
dataframe = pd.DataFrame({"car-series": series})
dataframe
# Out:
#   car-series
# 0        BMW
# 1       FORD
# 2     SHELBY
# 3     FERARI

# %%
netflix = pd.read_csv("netflix.csv")

# %%
netflix
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
# 5  80163890  TV Show                                  Apaches
# 6  70304989    Movie                                 Automata
# 7  80164077    Movie       Fabrizio Copano: Solo pienso en mi
# 8  80117902  TV Show                             Fire Chasers
#
#                           director  \
# 0         Richard Finn, Tim Maltby
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                 Fernando Lebrija
# 5                              NaN
# 6                      Gabe Ibáñez
# 7  Rodrigo Toro, Francisco Schultz
# ...

# %%
netflix.to_csv("exported-netflix-data.csv", index=False)

# %% [markdown]
# ## Describe data

# %%
netflix.dtypes
# Out:
# show_id          int64
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
#Attributes; columns is an attribute.
netflix_columns = netflix.columns

# %%
netflix_columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
#Functions. describe is a function.
netflix.describe()
# Out:
#             show_id  release_year
# count  9.000000e+00      9.000000
# mean   7.804811e+07   2016.111111
# std    4.422721e+06      1.763834
# min    7.023444e+07   2013.000000
# 25%    8.005865e+07   2016.000000
# 50%    8.011790e+07   2016.000000
# 75%    8.016389e+07   2017.000000
# max    8.114563e+07   2019.000000

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       9 non-null      int64
#  1   type          9 non-null      object
#  2   title         9 non-null      object
#  3   director      4 non-null      object
#  4   cast          8 non-null      object
#  5   country       9 non-null      object
#  6   date_added    9 non-null      object
#  7   release_year  9 non-null      int64
#  8   rating        9 non-null      object
#  9   duration      9 non-null      object
#  10  listed_in     9 non-null      object
#  11  description   9 non-null      object
# dtypes: int64(2), object(10)
# memory usage: 992.0+ bytes

# %%
len(netflix)
# Out:
# 9

# %%
netflix["release_year"].mean()
# Out:
# 2016.111111111111

# %%
netflix
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
# 5  80163890  TV Show                                  Apaches
# 6  70304989    Movie                                 Automata
# 7  80164077    Movie       Fabrizio Copano: Solo pienso en mi
# 8  80117902  TV Show                             Fire Chasers
#
#                           director  \
# 0         Richard Finn, Tim Maltby
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                 Fernando Lebrija
# 5                              NaN
# 6                      Gabe Ibáñez
# 7  Rodrigo Toro, Francisco Schultz
# ...

# %%
netflix_movies = netflix[netflix["type"] == "Movie"]

# %%
netflix_movies
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80117401  Movie               Jandino: Whatever it Takes
# 4  80125979  Movie                             #realityhigh
# 6  70304989  Movie                                 Automata
# 7  80164077  Movie       Fabrizio Copano: Solo pienso en mi
#
#                           director  \
# 0         Richard Finn, Tim Maltby
# 1                              NaN
# 4                 Fernando Lebrija
# 6                      Gabe Ibáñez
# 7  Rodrigo Toro, Francisco Schultz
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
# 6  Antonio Banderas, Dylan McDermott, Melanie Gri...
# 7                                    Fabrizio Copano
#
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
netflix["release_year"].plot()
# Out:
# <AxesSubplot:>

# %%
netflix
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
# 5  80163890  TV Show                                  Apaches
# 6  70304989    Movie                                 Automata
# 7  80164077    Movie       Fabrizio Copano: Solo pienso en mi
# 8  80117902  TV Show                             Fire Chasers
#
#                           director  \
# 0         Richard Finn, Tim Maltby
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                 Fernando Lebrija
# 5                              NaN
# 6                      Gabe Ibáñez
# 7  Rodrigo Toro, Francisco Schultz
# ...

# %%
netflix["rating"] = netflix["release_year"]*3/1000

# %%
netflix
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
# 5  80163890  TV Show                                  Apaches
# 6  70304989    Movie                                 Automata
# 7  80164077    Movie       Fabrizio Copano: Solo pienso en mi
# 8  80117902  TV Show                             Fire Chasers
#
#                           director  \
# 0         Richard Finn, Tim Maltby
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                 Fernando Lebrija
# 5                              NaN
# 6                      Gabe Ibáñez
# 7  Rodrigo Toro, Francisco Schultz
# ...

# %%
netflix.sample(frac=1)
# Out:
#     show_id     type                                    title  \
# 4  80125979    Movie                             #realityhigh
# 6  70304989    Movie                                 Automata
# 5  80163890  TV Show                                  Apaches
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 2  70234439  TV Show                       Transformers Prime
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 7  80164077    Movie       Fabrizio Copano: Solo pienso en mi
# 1  80117401    Movie               Jandino: Whatever it Takes
# 8  80117902  TV Show                             Fire Chasers
#
#                           director  \
# 4                 Fernando Lebrija
# 6                      Gabe Ibáñez
# 5                              NaN
# 3                              NaN
# 2                              NaN
# 0         Richard Finn, Tim Maltby
# 7  Rodrigo Toro, Francisco Schultz
# 1                              NaN
# ...
